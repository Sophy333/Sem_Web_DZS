# %% [markdown]
# OpenAI API

# %%
from openai import OpenAI
client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": "What is Theory of Mind?"}]
)
print(response.choices[0].message["content"])

# %% [markdown]
# PyTorch

# %%
# https://www.geeksforgeeks.org/deep-learning/pytorch-learn-with-examples/

import torch

tensor = torch.tensor([[1, 2], [3, 4], [5, 6]])

element = tensor[1, 0]
print(f"Indexed Element (Row 1, Column 0): {element}")  
slice_tensor = tensor[:2, :]
print(f"Sliced Tensor (First two rows): \n{slice_tensor}")

reshaped_tensor = tensor.view(2, 3)
print(f"Reshaped Tensor (2x3): \n{reshaped_tensor}")

# %%
# simple neural network with an input layer, a hidden layer, and an output layer
import torch
import torch.nn as nn

class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(2, 4)  
        self.fc2 = nn.Linear(4, 1)  

    def forward(self, x):
        x = torch.relu(self.fc1(x))  
        x = self.fc2(x)               
        return x

# %% [markdown]
# Hugging Face Transformers

# %%
# https://huggingface.co/docs/transformers/v4.15.0/en/quicktour

from transformers import pipeline
classifier = pipeline('sentiment-analysis')

classifier('We are very happy to show you the 🤗 Transformers library.')
#output: [{'label': 'POSITIVE', 'score': 0.9998}]

# or using direct model name 
classifier = pipeline('sentiment-analysis', model="nlptown/bert-base-multilingual-uncased-sentiment"),
